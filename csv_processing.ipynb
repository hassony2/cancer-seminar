# %%
import pandas as pd

# %%
df = pd.read_csv('../data/training-cancer-loc.csv')

# %%
df
# Out:
#      Patient_ID  Local_tumor_recurrence  Gender  Age_at_diagnosis      Race  \
# 0             1                       0    Male                58     White
# 1             2                       0  Female                78     White
# 2             3                       0    Male                57     White
# 3             4                       0  Female                56     White
# 4             5                       0  Female                60     White
# 5             6                       0    Male                66     White
# 6             7                       0  Female                72     White
# 7             8                       0    Male                77     White
# 8             9                       0  Female                71     White
# 9            10                       0    Male                50     White
# 10           11                       0    Male                50     White
# ...

# %%
df.Patient_ID
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c01549ed97ff> in <module>()
# ----> 1 pd.describe(df.Patient_ID)
#
# AttributeError: 'module' object has no attribute 'describe'

# %%
df.describe()
# Out:
#        Patient_ID  Local_tumor_recurrence  Age_at_diagnosis  T_category  \
# count  150.000000              150.000000        150.000000  150.000000
# mean    93.346667                0.080000         58.660000    2.206667
# std     65.378915                0.272202          8.889199    1.005333
# min      1.000000                0.000000         39.000000    1.000000
# 25%     45.250000                0.000000         52.000000    1.000000
# 50%     86.500000                0.000000         58.000000    2.000000
# 75%    126.750000                0.000000         65.000000    3.000000
# max    313.000000                1.000000         89.000000    4.000000
#
#        Smoking_Pack-Years  Radiation_treatment_course_duration  \
# count          141.000000                           150.000000
# mean            18.730496                            42.493333
# std             22.199060                             3.347335
# min              0.000000                            34.000000
# ...

# %%
true_positives = len(df[df.Local_tumor_recurrence == 1])
print('true_positives : {tp}'.format(tp = true_positives))
# Out:
# true_positives : 12

# %%
df[df.Local_tumor_recurrence == 1]
# Out:
#      Patient_ID  Local_tumor_recurrence  Gender  Age_at_diagnosis      Race  \
# 11           12                       1    Male                54     White
# 21           25                       1    Male                67     White
# 32           39                       1    Male                45     White
# 35           43                       1    Male                54     White
# 40           48                       1    Male                50     White
# 68           79                       1    Male                63     White
# 116         132                       1    Male                65     White
# 138         174                       1  Female                60     White
# 139         178                       1    Male                64     White
# 142         196                       1    Male                79     White
# 144         276                       1    Male                65     White
# ...
